# %% [markdown]
# # SQL-Python
# This notebook will show how python process the dataset as SQL.
# **Chooce a simple example database**

# %%
import pandas as pd
#import numpy as np

# %%
# read data from csv file
us_baby_names=pd.read_csv("D:\OZAI\Learn\Python\Introduction to Data Science\Ex_Files_Intro_to_Data_Science\Exercise Files\state_baby_names.csv")
us_baby_names
# Out:
#               Id      Name  Year Gender State  Count
# 0              1      Mary  1910      F    AK     14
# 1              2     Annie  1910      F    AK     12
# 2              3      Anna  1910      F    AK     10
# 3              4  Margaret  1910      F    AK      8
# 4              5     Helen  1910      F    AK      7
# ...          ...       ...   ...    ...   ...    ...
# 5647421  5647422      Seth  2014      M    WY      5
# 5647422  5647423   Spencer  2014      M    WY      5
# 5647423  5647424      Tyce  2014      M    WY      5
# 5647424  5647425    Victor  2014      M    WY      5
# 5647425  5647426    Waylon  2014      M    WY      5
#
# [5647426 rows x 6 columns]

# %%
us_baby_names.loc[us_baby_names['Year']>2004].to_csv('state_baby_names.csv',index=False)

# %%
state_baby_names=pd.read_csv("state_baby_names.csv")
state_baby_names
# Out:
#              Id      Name  Year Gender State  Count
# 0         11554   Madison  2005      F    AK     53
# 1         11555      Emma  2005      F    AK     49
# 2         11556     Emily  2005      F    AK     47
# 3         11557  Isabella  2005      F    AK     35
# 4         11558  Samantha  2005      F    AK     35
# ...         ...       ...   ...    ...   ...    ...
# 929970  5647422      Seth  2014      M    WY      5
# 929971  5647423   Spencer  2014      M    WY      5
# 929972  5647424      Tyce  2014      M    WY      5
# 929973  5647425    Victor  2014      M    WY      5
# 929974  5647426    Waylon  2014      M    WY      5
#
# [929975 rows x 6 columns]

# %%
state = pd.unique(state_baby_names['State'])
dim_state=pd.DataFrame({'State_Id':range(1001,1001+len(state)),'State':state})
dim_state.head()
# Out:
#    State_Id State
# 0      1001    AK
# 1      1002    AL
# 2      1003    AR
# 3      1004    AZ
# 4      1005    CA

# %%
baby_names = state_baby_names.join(dim_state.set_index('State'),on='State').drop(columns=['State'])
baby_names
# Out:
#              Id      Name  Year Gender State  Count
# 0         11554   Madison  2005      F    AK     53
# 1         11555      Emma  2005      F    AK     49
# 2         11556     Emily  2005      F    AK     47
# 3         11557  Isabella  2005      F    AK     35
# 4         11558  Samantha  2005      F    AK     35
# ...         ...       ...   ...    ...   ...    ...
# 929970  5647422      Seth  2014      M    WY      5
# 929971  5647423   Spencer  2014      M    WY      5
# 929972  5647424      Tyce  2014      M    WY      5
# 929973  5647425    Victor  2014      M    WY      5
# 929974  5647426    Waylon  2014      M    WY      5
#
# [929975 rows x 6 columns]

# %%
# Out:
#    State_Id State
# 0      1001    AK
# 1      1002    AL
# 2      1003    AR
# 3      1004    AZ
# 4      1005    CA

# %% [markdown]
# ## Prepare the original data
# > * **database:**
# >   * netflix
# > * **dataframe:**
# >   * netflix

# %% [markdown]
# ## Create a country dimention table, extract the data from the field country of netflix
# > * **database:**
# >   * netflix
# >   * country
# > * **dataframe:**
# >   * netflix
# >   * country

# %% [markdown]
# ## null processing

# %% [markdown]
# ## Sub dataset

# %% [markdown]
# ## top/limit
# ## distinct
# ## delete duplicate data
# ## update
# df.loc[['viper', 'sidewinder'], ['shield']] = 50
# df
#             max_speed  shield
# cobra               1       2
# viper               4      50
# sidewinder          7      50
#
# ## Column alias
# ## case when
# ## data type : cast
# ## date function
#
# ## where
#
# ## over partition??
# ## inner/out Join

# %% [markdown]
# ## top/limit

# %%
iloc
head

# %% [markdown]
# ## where

# %%
loc

# %% [markdown]
# ## order by

# %%
netflix.sort_values(['type','country'],ascending=[False,True])
# Out:
#      show_id     type                                              title  \
# 249    s1222  TV Show                    Carmel: Who Killed Maria Marta?
# 591    s1530  TV Show                                           Creators
# 1029   s1925  TV Show                                               Edha
# 1068   s1960  TV Show                                        El Marginal
# 1611   s2449  TV Show                                  Go! Live Your Way
# ...      ...      ...                                                ...
# 7625    s853    Movie                              Best of Stand-Up 2020
# 7652    s878    Movie  Beyond the Boundary: ICC Women's T20 World Cup...
# 7666    s890    Movie                                          Bheemayan
# 7701    s921    Movie                            Bill Hicks: Reflections
# 7765     s98    Movie                                        3 Deewarein
#
#                 director                                               cast  \
# ...

# %%
netflix_t=pd.read_sql("SELECT * FROM netflix order by type desc, country asc", conn)
netflix_t
# Out:
#      show_id     type                           title  \
# 0      s1013  TV Show  Bob Ross: Beauty Is Everywhere
# 1      s1019  TV Show     Bobby Kennedy for President
# 2      s1022  TV Show       Boca Juniors Confidential
# 3      s1047  TV Show                   Border Patrol
# 4      s1076  TV Show                      Brainchild
# ...      ...      ...                             ...
# 7782   s3106    Movie                         Jackpot
# 7783    s940    Movie                   Bitcoin Heist
# 7784   s5655    Movie             Sky Tour: The Movie
# 7785   s2758    Movie               Hitler - A Career
# 7786   s1494    Movie                        Cook Off
#
#                                    director  \
# 0                                      None
# 1                               Dawn Porter
# 2                                      None
# 3                                      None
# 4                                      None
# ...

# %% [markdown]
# ## group by and aggeragate

# %%
#netflix.groupby(['type']).agg({'date_added':['max'],'release_year':['min']})
df=netflix[['type','date_added','release_year','duration']]
df.info()
df.groupby('type').agg('max')
#netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          7787 non-null   object
#  1   date_added    7777 non-null   object
#  2   release_year  7787 non-null   int64
#  3   duration      7787 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 243.5+ KB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\python310\lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# ...

# %%
select type
,max(date_added)
,min(release_year)
from netflix
group by type;

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int64
#  1   B       4 non-null      int64
#  2   C       4 non-null      float64
# dtypes: float64(1), int64(2)
# memory usage: 224.0 bytes

# %%
# Out:
#    B         C
# A
# 1  1  0.227877
# 2  3 -0.562860
